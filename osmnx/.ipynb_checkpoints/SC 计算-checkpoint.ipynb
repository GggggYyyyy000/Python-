# %%
import matplotlib.cm as cm
import networkx as nx
import numpy as np
import osmnx as ox
import pandas as pd
import geopandas as gpd
import math

# %matplotlib inline
ox.__version__
# Out:
# '1.0.1'

# %% [markdown]
# # 单数据测试

# %%
file_path = "/Users/creative/Desktop/datas.geojson"

# %%
gdf = gpd.read_file(file_path)
gdf = gdf.to_crs("EPSG:4326")

# %%
"""用polygon爬取"""
G = ox.graph_from_polygon(gdf['geometry'][0], network_type='all',simplify=True, clean_periphery=True)
ox.plot_graph(G)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
ox.save_graph_shapefile(G, filepath='./data/piedmont')

# %%
area = math.pi * 1098*1098

# %%
G_proj = ox.project_graph(G)
G2 = ox.consolidate_intersections(G_proj, rebuild_graph=True, tolerance=20, dead_ends=False)

# %%
ox.save_graph_shapefile(G2, filepath='./data/piedmont')

# %%
stats = ox.basic_stats(G2,area)

# %%
sc = []
sc.append({"intersection_density":round(stats["intersection_density_km"],2),
      "street_density":round(stats["street_density_km"],2),
      "link_node_radio":round(stats["streets_per_node_avg"],2)})

# %%
sc
# Out:
# [{'intersection_density': 34.32,
#   'street_density': 20081.52,
#   'link_node_radio': 1.84}]

# %% [markdown]
# # 测试代码

# %%
file_path = "/Users/creative/Documents/python/osmnx/overpass/state_border_saxony.xml"

# %%
G = ox.graph_from_xml(file_path,simplify=True)

# %%
ox.plot_graph(G)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
G_proj = ox.project_graph(G)
G2 = ox.consolidate_intersections(G_proj, rebuild_graph=True, tolerance=20, dead_ends=False)
stats = ox.basic_stats(G2)

# %%
stats
# Out:
# {'n': 103,
#  'm': 430,
#  'k_avg': 8.349514563106796,
#  'intersection_count': 103,
#  'streets_per_node_avg': 4.174757281553398,
#  'streets_per_node_counts': {0: 0, 1: 0, 2: 2, 3: 0, 4: 90, 5: 0, 6: 11},
#  'streets_per_node_proportion': {0: 0.0,
#   1: 0.0,
#   2: 0.019417475728155338,
#   3: 0.0,
#   4: 0.8737864077669902,
#   5: 0.0,
#   6: 0.10679611650485436},
#  'edge_length_total': 345214.8002742744,
#  'edge_length_avg': 802.8251169169173,
#  'street_length_total': 172607.40013713742,
#  'street_length_avg': 802.8251169169182,
#  'street_segments_count': 215,
#  'node_density_km': None,
#  'intersection_density_km': None,
#  'edge_density_km': None,
#  'street_density_km': None,
#  'circuity_avg': 0.0001019373420003588,
#  'self_loop_proportion': 0.0,
#  'clean_intersection_count': None,
#  'clean_intersection_density_km': None}

# %% [markdown]
# # 计算代码

# %% [markdown]
# # 2021年数据计算

# %%
file_path = "D:\\2020 毕业论文\\中期检查\\Database\\07-connectivity\\Result\\buff_1098.shp"
gdf = gpd.read_file(file_path)
gdf = gdf.to_crs("EPSG:4326")

# %%
def SC(geo_boundary,park):
    area = math.pi * 1098*1098
    G = ox.graph_from_polygon(geo_boundary, network_type='all')
    G_proj = ox.project_graph(G)
    G2 = ox.consolidate_intersections(G_proj, rebuild_graph=True, tolerance=15, dead_ends=False) #简化路网
    stats = ox.basic_stats(G2, area=area)
    return {"park":park,"intersection_density":round(stats["intersection_density_km"],2),
          "street_density":round(stats["street_density_km"],2),
          "link_node_radio":round(stats["streets_per_node_avg"],2)}

# %%
from tqdm import tqdm

sc = []
for i in tqdm(range(244,len(gdf))):
    park = gdf.loc[i,"公园名"]
    geo_boundary = gdf.loc[i,"geometry"]
    sc.append(SC(geo_boundary,park))
# Out:
# 100%|██████████| 128/128 [14:18<00:00,  6.71s/it]

# %%
sc
# Out:
# [{'park': '衙边社区公园',
#   'intersection_density': 6.6,
#   'street_density': 4763.78,
#   'link_node_radio': 1.81},
#  {'park': '沙一公园',
#   'intersection_density': 11.88,
#   'street_density': 7055.69,
#   'link_node_radio': 1.92},
#  {'park': '东塘社区公园',
#   'intersection_density': 9.5,
#   'street_density': 5871.11,
#   'link_node_radio': 2.07},
#  {'park': '坣岗社区公园',
#   'intersection_density': 10.3,
#   'street_density': 5206.96,
#   'link_node_radio': 2.16},
#  {'park': '新桥社区公园',
#   'intersection_density': 17.95,
#   'street_density': 6783.82,
#   'link_node_radio': 2.51},
#  {'park': '燕川燕岭社区公园',
#   'intersection_density': 6.07,
#   'street_density': 3266.41,
#   'link_node_radio': 2.89},
#  {'park': '罗田社区公园',
#   'intersection_density': 3.96,
#   'street_density': 3705.31,
#   'link_node_radio': 2.0},
#  {'park': '东方社区公园',
#   'intersection_density': 6.6,
#   'street_density': 4981.57,
#   'link_node_radio': 1.98},
#  {'park': '花果山村',
#   'intersection_density': 20.33,
#   'street_density': 8079.43,
#   'link_node_radio': 2.35},
#  {'park': '东风公园',
#   'intersection_density': 21.12,
#   'street_density': 7432.23,
#   'link_node_radio': 2.5},
#  {'park': '燕山公园',
#   'intersection_density': 12.15,
#   'street_density': 4378.64,
#   'link_node_radio': 2.7},
#  {'park': '燕塘河堤公园',
#   'intersection_density': 6.6,
#   'street_density': 2518.59,
#   'link_node_radio': 2.44},
#  {'park': '和一社区公园',
#   'intersection_density': 17.16,
#   'street_density': 6175.61,
#   'link_node_radio': 2.34},
#  {'park': '塘尾社区公园',
#   'intersection_density': 10.56,
#   'street_density': 7608.17,
#   'link_node_radio': 1.68},
#  {'park': '上寮社区公园',
#   'intersection_density': 17.16,
#   'street_density': 7313.07,
#   'link_node_radio': 2.54},
#  {'park': '上寮荔枝社区公园',
#   'intersection_density': 16.9,
#   'street_density': 6885.43,
#   'link_node_radio': 2.49},
#  {'park': '塘头石山公园',
#   'intersection_density': 10.3,
#   'street_density': 5720.82,
#   'link_node_radio': 2.42},
#  {'park': '塘头新社区公园',
#   'intersection_density': 11.35,
#   'street_density': 5963.03,
#   'link_node_radio': 2.46},
#  {'park': '塘下涌红围社区公园',
#   'intersection_density': 7.92,
#   'street_density': 3497.8,
#   'link_node_radio': 2.97},
#  {'park': '下山门社区公园',
#   'intersection_density': 13.2,
#   'street_density': 5610.37,
#   'link_node_radio': 2.49},
#  {'park': '山门社区公园',
#   'intersection_density': 7.39,
#   'street_density': 3945.74,
#   'link_node_radio': 2.21},
#  {'park': '楼岗社区户外文体公园',
#   'intersection_density': 5.28,
#   'street_density': 2697.69,
#   'link_node_radio': 2.31},
#  {'park': '碧头社区公园',
#   'intersection_density': 9.77,
#   'street_density': 3789.03,
#   'link_node_radio': 2.77},
#  {'park': '沙浦社区公园',
#   'intersection_density': 12.94,
#   'street_density': 4192.74,
#   'link_node_radio': 3.0},
#  {'park': '步涌宗汉祖社区公园',
#   'intersection_density': 5.81,
#   'street_density': 4282.75,
#   'link_node_radio': 1.95},
#  {'park': '凤凰社区公园',
#   'intersection_density': 6.34,
#   'street_density': 3783.15,
#   'link_node_radio': 2.13},
#  {'park': '塘尾村社区公园',
#   'intersection_density': 16.37,
#   'street_density': 8524.6,
#   'link_node_radio': 1.88},
#  {'park': '新荔公园',
#   'intersection_density': 17.69,
#   'street_density': 6626.56,
#   'link_node_radio': 2.68},
#  {'park': '桥头社区公园',
#   'intersection_density': 21.39,
#   'street_density': 7907.43,
#   'link_node_radio': 2.22},
#  {'park': '福永社区公园',
#   'intersection_density': 21.12,
#   'street_density': 7346.25,
#   'link_node_radio': 2.61},
#  {'park': '怀德西门公园',
#   'intersection_density': 21.65,
#   'street_density': 6910.24,
#   'link_node_radio': 2.71},
#  {'park': '新和公园',
#   'intersection_density': 26.67,
#   'street_density': 8475.91,
#   'link_node_radio': 2.72},
#  {'park': '水田社区公园',
#   'intersection_density': 8.18,
#   'street_density': 3369.73,
#   'link_node_radio': 2.42},
#  {'park': '河滨公园',
#   'intersection_density': 15.58,
#   'street_density': 6047.77,
#   'link_node_radio': 2.33},
#  {'park': '石岩市民广场公园',
#   'intersection_density': 15.84,
#   'street_density': 6896.04,
#   'link_node_radio': 2.26},
#  {'park': '官田公园',
#   'intersection_density': 13.2,
#   'street_density': 5841.02,
#   'link_node_radio': 2.3},
#  {'park': '官田社区公园',
#   'intersection_density': 12.94,
#   'street_density': 5313.81,
#   'link_node_radio': 2.29},
#  {'park': '宝源新村公园',
#   'intersection_density': 50.69,
#   'street_density': 14596.92,
#   'link_node_radio': 2.34},
#  {'park': '麻布社区公园（1）',
#   'intersection_density': 48.05,
#   'street_density': 15732.05,
#   'link_node_radio': 2.34},
#  {'park': '河东公园',
#   'intersection_density': 32.74,
#   'street_density': 10666.07,
#   'link_node_radio': 2.5},
#  {'park': '文雅社区公园',
#   'intersection_density': 24.55,
#   'street_density': 10526.33,
#   'link_node_radio': 2.35},
#  {'park': '海华公园',
#   'intersection_density': 36.44,
#   'street_density': 16108.13,
#   'link_node_radio': 2.03},
#  {'park': '海裕社区公园',
#   'intersection_density': 42.77,
#   'street_density': 21096.07,
#   'link_node_radio': 1.86},
#  {'park': '海旺社区公园',
#   'intersection_density': 37.76,
#   'street_density': 20666.08,
#   'link_node_radio': 1.87},
#  {'park': '上川公园',
#   'intersection_density': 14.79,
#   'street_density': 6210.62,
#   'link_node_radio': 2.54},
#  {'park': '福围社区公园',
#   'intersection_density': 20.59,
#   'street_density': 9599.37,
#   'link_node_radio': 2.38},
#  {'park': '草围公园',
#   'intersection_density': 33.0,
#   'street_density': 10187.23,
#   'link_node_radio': 2.61},
#  {'park': '黄田公园',
#   'intersection_density': 35.12,
#   'street_density': 10596.7,
#   'link_node_radio': 2.62},
#  {'park': '料坑社区公园',
#   'intersection_density': 14.52,
#   'street_density': 3670.93,
#   'link_node_radio': 2.69},
#  {'park': '民主社区公园',
#   'intersection_density': 9.24,
#   'street_density': 3802.75,
#   'link_node_radio': 2.35},
#  {'park': '坣岗荔枝公园',
#   'intersection_density': 9.5,
#   'street_density': 5473.09,
#   'link_node_radio': 2.0},
#  {'park': '沙井中心公园',
#   'intersection_density': 10.03,
#   'street_density': 4412.06,
#   'link_node_radio': 2.22},
#  {'park': '凤凰广场公园',
#   'intersection_density': 15.84,
#   'street_density': 6414.04,
#   'link_node_radio': 2.65},
#  {'park': '楼岗社区公园',
#   'intersection_density': 13.99,
#   'street_density': 6170.8,
#   'link_node_radio': 2.3},
#  {'park': '潭头村社区公园',
#   'intersection_density': 19.27,
#   'street_density': 6409.53,
#   'link_node_radio': 2.67},
#  {'park': '燕川社区公园',
#   'intersection_density': 9.24,
#   'street_density': 3881.62,
#   'link_node_radio': 2.8},
#  {'park': '新安荔枝公园',
#   'intersection_density': 35.64,
#   'street_density': 10953.58,
#   'link_node_radio': 2.37},
#  {'park': '海乐社区公园',
#   'intersection_density': 39.6,
#   'street_density': 15116.5,
#   'link_node_radio': 2.12},
#  {'park': '新乐社区公园',
#   'intersection_density': 39.34,
#   'street_density': 15037.32,
#   'link_node_radio': 2.13},
#  {'park': '金雅园社区公园',
#   'intersection_density': 27.72,
#   'street_density': 9166.04,
#   'link_node_radio': 2.43},
#  {'park': '碧岭社区公园',
#   'intersection_density': 3.43,
#   'street_density': 1560.78,
#   'link_node_radio': 3.46},
#  {'park': '东四路街心公园',
#   'intersection_density': 5.02,
#   'street_density': 4250.08,
#   'link_node_radio': 1.93},
#  {'park': '燕子岭社区公园',
#   'intersection_density': 8.45,
#   'street_density': 3526.48,
#   'link_node_radio': 2.46},
#  {'park': '竹坑公园',
#   'intersection_density': 5.02,
#   'street_density': 3536.19,
#   'link_node_radio': 1.97},
#  {'park': '竹坑西坑上坝社区公园',
#   'intersection_density': 5.54,
#   'street_density': 4128.14,
#   'link_node_radio': 2.06},
#  {'park': '坪山文化广场',
#   'intersection_density': 21.39,
#   'street_density': 6306.44,
#   'link_node_radio': 2.67},
#  {'park': '东海岸运动公园',
#   'intersection_density': 16.9,
#   'street_density': 5392.13,
#   'link_node_radio': 2.42},
#  {'park': '黄必围社区公园',
#   'intersection_density': 14.26,
#   'street_density': 5682.48,
#   'link_node_radio': 2.33},
#  {'park': '明珠文体公园',
#   'intersection_density': 11.88,
#   'street_density': 6277.88,
#   'link_node_radio': 2.39},
#  {'park': '内湖公园',
#   'intersection_density': 22.18,
#   'street_density': 8355.02,
#   'link_node_radio': 2.26},
#  {'park': '小梅沙生态公园',
#   'intersection_density': 7.92,
#   'street_density': 4191.39,
#   'link_node_radio': 2.71},
#  {'park': '爱国路社区公园',
#   'intersection_density': 31.15,
#   'street_density': 9792.35,
#   'link_node_radio': 2.4},
#  {'park': '翠竹文体公园',
#   'intersection_density': 44.62,
#   'street_density': 11611.22,
#   'link_node_radio': 2.57},
#  {'park': '黄贝岭山公园',
#   'intersection_density': 40.4,
#   'street_density': 12661.78,
#   'link_node_radio': 2.4},
#  {'park': '深港花园、集萃园、清和园社区公园',
#   'intersection_density': 33.8,
#   'street_density': 10392.86,
#   'link_node_radio': 2.46},
#  {'park': '笋岗路小游园',
#   'intersection_density': 51.22,
#   'street_density': 15095.55,
#   'link_node_radio': 2.16},
#  {'park': '特检苑文体公园',
#   'intersection_density': 9.24,
#   'street_density': 4205.17,
#   'link_node_radio': 2.18},
#  {'park': '九祥岭公园ZH24',
#   'intersection_density': 24.82,
#   'street_density': 6441.54,
#   'link_node_radio': 2.65},
#  {'park': '大学城生态公园',
#   'intersection_density': 26.14,
#   'street_density': 7442.09,
#   'link_node_radio': 2.45},
#  {'park': '南油公园',
#   'intersection_density': 48.32,
#   'street_density': 13703.65,
#   'link_node_radio': 2.33},
#  {'park': '沙河西路街心公园',
#   'intersection_density': 34.85,
#   'street_density': 16620.3,
#   'link_node_radio': 1.85},
#  {'park': '桂花路都市公园',
#   'intersection_density': 26.67,
#   'street_density': 11247.17,
#   'link_node_radio': 2.23},
#  {'park': '水围恒春园',
#   'intersection_density': 51.75,
#   'street_density': 17925.56,
#   'link_node_radio': 2.19},
#  {'park': '福田人民医院社区公园',
#   'intersection_density': 56.24,
#   'street_density': 16923.86,
#   'link_node_radio': 2.18},
#  {'park': '华富街心公园',
#   'intersection_density': 57.56,
#   'street_density': 16411.39,
#   'link_node_radio': 2.21},
#  {'park': '深南小游园',
#   'intersection_density': 48.58,
#   'street_density': 15108.49,
#   'link_node_radio': 2.3},
#  {'park': '新洲石厦中学社区公园',
#   'intersection_density': 46.73,
#   'street_density': 14629.54,
#   'link_node_radio': 2.37},
#  {'park': '新洲岁宝社区公园',
#   'intersection_density': 47.79,
#   'street_density': 19648.3,
#   'link_node_radio': 1.91},
#  {'park': '坑梓大水湾社区公园',
#   'intersection_density': 7.39,
#   'street_density': 3696.52,
#   'link_node_radio': 2.44},
#  {'park': '坪山三洋湖公园',
#   'intersection_density': 17.69,
#   'street_density': 5428.28,
#   'link_node_radio': 2.67},
#  {'park': '汤坑社区公园',
#   'intersection_density': 5.02,
#   'street_density': 2849.12,
#   'link_node_radio': 2.57},
#  {'park': '龙田社区荔枝公园',
#   'intersection_density': 6.86,
#   'street_density': 4972.81,
#   'link_node_radio': 1.62},
#  {'park': '街心公园',
#   'intersection_density': 9.5,
#   'street_density': 5599.08,
#   'link_node_radio': 2.04},
#  {'park': '横岗社区公园',
#   'intersection_density': 31.95,
#   'street_density': 8101.53,
#   'link_node_radio': 2.85},
#  {'park': '白泥坑水库公园',
#   'intersection_density': 0.79,
#   'street_density': 125.64,
#   'link_node_radio': 3.0},
#  {'park': '杜鹃公园',
#   'intersection_density': 8.18,
#   'street_density': 2538.81,
#   'link_node_radio': 3.06},
#  {'park': '南坑社区公园',
#   'intersection_density': 11.09,
#   'street_density': 4338.21,
#   'link_node_radio': 2.49},
#  {'park': '南岭村社区公园',
#   'intersection_density': 21.39,
#   'street_density': 5883.26,
#   'link_node_radio': 2.97},
#  {'park': '南约社区公园',
#   'intersection_density': 4.22,
#   'street_density': 2763.58,
#   'link_node_radio': 1.96},
#  {'park': '首创社区公园',
#   'intersection_density': 11.09,
#   'street_density': 5031.36,
#   'link_node_radio': 2.65},
#  {'park': '天健现代城社区公园',
#   'intersection_density': 15.58,
#   'street_density': 8497.09,
#   'link_node_radio': 2.49},
#  {'park': '西坑小学公园',
#   'intersection_density': 4.49,
#   'street_density': 1905.64,
#   'link_node_radio': 2.74},
#  {'park': '坪山儿童公园',
#   'intersection_density': 7.92,
#   'street_density': 3429.38,
#   'link_node_radio': 2.43},
#  {'park': '大鹏儿童公园',
#   'intersection_density': 2.38,
#   'street_density': 1293.35,
#   'link_node_radio': 1.69},
#  {'park': '碧泰园',
#   'intersection_density': 10.83,
#   'street_density': 3580.2,
#   'link_node_radio': 2.87},
#  {'park': '壆岗荔枝公园',
#   'intersection_density': 8.71,
#   'street_density': 5336.07,
#   'link_node_radio': 1.91},
#  {'park': '壆岗长廊文化公园',
#   'intersection_density': 7.13,
#   'street_density': 5082.28,
#   'link_node_radio': 1.89},
#  {'park': '海富社区公园',
#   'intersection_density': 40.92,
#   'street_density': 18425.49,
#   'link_node_radio': 1.96},
#  {'park': '留仙三路北社区公园',
#   'intersection_density': 21.91,
#   'street_density': 6959.9,
#   'link_node_radio': 2.51},
#  {'park': '留仙三路南社区公园',
#   'intersection_density': 21.65,
#   'street_density': 6918.23,
#   'link_node_radio': 2.52},
#  {'park': '沙浦体育公园',
#   'intersection_density': 9.77,
#   'street_density': 5869.44,
#   'link_node_radio': 2.12},
#  {'park': '沙浦围茅州公园',
#   'intersection_density': 4.75,
#   'street_density': 2159.02,
#   'link_node_radio': 2.52},
#  {'park': '沙浦围社区公园',
#   'intersection_density': 12.41,
#   'street_density': 4776.32,
#   'link_node_radio': 2.85},
#  {'park': '上排社区公园',
#   'intersection_density': 6.6,
#   'street_density': 4613.11,
#   'link_node_radio': 1.84},
#  {'park': '石岩社区公园',
#   'intersection_density': 15.58,
#   'street_density': 6559.52,
#   'link_node_radio': 2.29},
#  {'park': '同富裕公园',
#   'intersection_density': 15.05,
#   'street_density': 6176.75,
#   'link_node_radio': 2.26},
#  {'park': '乌龙山社区公园',
#   'intersection_density': 6.86,
#   'street_density': 3215.02,
#   'link_node_radio': 2.61},
#  {'park': '裕安街心社区公园',
#   'intersection_density': 23.5,
#   'street_density': 8489.5,
#   'link_node_radio': 2.44},
#  {'park': '长乐社区公园',
#   'intersection_density': 35.12,
#   'street_density': 15763.87,
#   'link_node_radio': 1.93},
#  {'park': '白石厦中心公园',
#   'intersection_density': 22.97,
#   'street_density': 8021.95,
#   'link_node_radio': 2.76},
#  {'park': '求雨岭城市公园',
#   'intersection_density': 4.75,
#   'street_density': 1880.62,
#   'link_node_radio': 2.59},
#  {'park': '牛湖新艺公园',
#   'intersection_density': 8.45,
#   'street_density': 3185.03,
#   'link_node_radio': 2.37},
#  {'park': '毓林公园',
#   'intersection_density': 7.39,
#   'street_density': 3585.58,
#   'link_node_radio': 2.44},
#  {'park': '大浪社区户外文体广场',
#   'intersection_density': 19.8,
#   'street_density': 8405.09,
#   'link_node_radio': 2.21},
#  {'park': '长圳公园Ⅱ',
#   'intersection_density': 15.31,
#   'street_density': 6532.85,
#   'link_node_radio': 2.42},
#  {'park': '甲子塘公园Ⅰ',
#   'intersection_density': 11.09,
#   'street_density': 5061.43,
#   'link_node_radio': 2.55},
#  {'park': '甲子塘激光视盘基地公共绿地广场',
#   'intersection_density': 10.3,
#   'street_density': 3988.54,
#   'link_node_radio': 2.54},
#  {'park': '甲子塘社区公园Ⅱ',
#   'intersection_density': 11.09,
#   'street_density': 4391.32,
#   'link_node_radio': 2.69}]

# %%
len(data)
# Out:
# 244

# %%
df = pd.DataFrame(columns=["park","intersection_density","street_density","link_node_radio"])  #构建一个空表
df = df.append(sc,ignore_index=True)
df.to_excel("SC_result20212.xlsx")

# %% [markdown]
# # 历史数据计算

# %%
df["street_density"] = df["street_density"]/1000

# %%
df.to_excel("SC_result2021.xlsx")
