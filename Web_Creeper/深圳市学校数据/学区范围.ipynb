# %%
import json

# %%
with open("mapjson.json",'r') as load_f:
    load_dict = json.load(load_f)

# %%
load_dict
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'id': 3,
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[113.806128, 22.668471],
#       [113.805389, 22.66903],
#       [113.80278, 22.671006],
#       [113.80228, 22.672215],
#       [113.802066, 22.673443],
#       [113.801765, 22.677799],
#       [113.806643, 22.677422],
#       [113.808371, 22.677402],
#       [113.808392, 22.677363],
#       [113.809969, 22.677492],
#       [113.809959, 22.678264],
#       [113.81299, 22.678107],
#       [113.813065, 22.675939],
#       [113.820658, 22.683453],
#       [113.820272, 22.68767],
#       [113.821516, 22.687373],
#       [113.823968, 22.68967],
#       [113.823212, 22.69062],
#       [113.824188, 22.691481],
#       [113.825637, 22.691892],
#       [113.82613, 22.691912],
#       [113.826072, 22.693062],
#       [113.828545, 22.694358],
#       [113.829811, 22.694747],
#       [113.828573, 22.695916],
#       [113.827035, 22.697248],
# ...
